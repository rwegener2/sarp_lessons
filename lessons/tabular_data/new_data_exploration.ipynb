# %%
import geopandas as gpd
import pandas as pd

# %%
pd.read_csv('./data/MER-WAS_DC8_20160806_R27.ict', skiprows=11)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/f8/rh42xb3d1tnbw2bxsjwgym1c0000gn/T/ipykernel_9187/1279474214.py in <module>
# ----> 1 pd.read_csv('./data/MER-WAS_DC8_20160806_R27.ict', skiprows=11)
#
# ~/.pyenv/versions/miniconda3-4.7.12/envs/sarp_docs/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ## Aeronet
#
# https://aeronet.gsfc.nasa.gov/cgi-bin/webtool_aod_v3
#
# Got it open!  But it looks like edwards is a pretty sparse dataset.
# I'd go look for another year or location.

# %%
pd.read_csv('./data/20210101_20211231_ECCOE-Edwards-AFB.lev20 2', skiprows=6)
# Out:
#     Date(dd:mm:yyyy) Time(hh:mm:ss)  Day_of_Year  Day_of_Year(Fraction)  \
# 0         21:07:2021       16:13:20          202             202.675926
# 1         21:07:2021       16:33:20          202             202.689815
# 2         21:07:2021       16:38:20          202             202.693287
# 3         21:07:2021       16:43:20          202             202.696759
# 4         21:07:2021       16:48:20          202             202.700231
# ..               ...            ...          ...                    ...
# 152       22:07:2021       22:58:24          203             203.957222
# 153       22:07:2021       23:07:52          203             203.963796
# 154       22:07:2021       23:17:34          203             203.970532
# 155       22:07:2021       23:23:24          203             203.974583
# 156       22:07:2021       23:28:24          203             203.978056
#
#      AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  AOD_675nm  ...  \
# ...

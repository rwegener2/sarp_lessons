# %%
import xarray as xr

# %% [markdown]
# Open the Landsat file in xarray.

# %%
red = xr.open_rasterio('/Users/rwegener/Downloads/LC08_L2SP_025029_20170422_20200904_02_T1_SR_B5.TIF')
nir = xr.open_rasterio('/Users/rwegener/Downloads/LC08_L2SP_025029_20170422_20200904_02_T1_SR_B4.TIF')
# Out:
# /var/folders/f8/rh42xb3d1tnbw2bxsjwgym1c0000gn/T/ipykernel_4081/2849036254.py:1: DeprecationWarning: open_rasterio is Deprecated in favor of rioxarray. For information about transitioning, see: https://corteva.github.io/rioxarray/stable/getting_started/getting_started.html
#   red = xr.open_rasterio('/Users/rwegener/Downloads/LC08_L2SP_025029_20170422_20200904_02_T1_SR_B5.TIF')
# /var/folders/f8/rh42xb3d1tnbw2bxsjwgym1c0000gn/T/ipykernel_4081/2849036254.py:2: DeprecationWarning: open_rasterio is Deprecated in favor of rioxarray. For information about transitioning, see: https://corteva.github.io/rioxarray/stable/getting_started/getting_started.html
#   nir = xr.open_rasterio('/Users/rwegener/Downloads/LC08_L2SP_025029_20170422_20200904_02_T1_SR_B4.TIF')

# %% [markdown]
# Take a moment to inspect the graphical representation. What are the variables? How many dimensions and coordinates?

# %%
nir
# Out:
# <xarray.DataArray (band: 1, y: 7771, x: 7651)>
# [59455921 values with dtype=uint16]
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 5.059e+06 5.059e+06 5.059e+06 ... 4.826e+06 4.826e+06
#   * x        (x) float64 5.865e+05 5.865e+05 5.866e+05 ... 8.16e+05 8.16e+05
# Attributes:
#     transform:      (30.0, 0.0, 586485.0, 0.0, -30.0, 5058615.0)
#     crs:            +init=epsg:32615
#     res:            (30.0, 30.0)
#     is_tiled:       1
#     nodatavals:     (0.0,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     AREA_OR_POINT:  Point

# %%
red
# Out:
# <xarray.DataArray (band: 1, y: 7771, x: 7651)>
# [59455921 values with dtype=uint16]
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 5.059e+06 5.059e+06 5.059e+06 ... 4.826e+06 4.826e+06
#   * x        (x) float64 5.865e+05 5.865e+05 5.866e+05 ... 8.16e+05 8.16e+05
# Attributes:
#     transform:      (30.0, 0.0, 586485.0, 0.0, -30.0, 5058615.0)
#     crs:            +init=epsg:32615
#     res:            (30.0, 30.0)
#     is_tiled:       1
#     nodatavals:     (0.0,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     AREA_OR_POINT:  Point

# %% [markdown]
# Subset to 1 slice of data and use the `.plot()` function to get a quick look at it. Do you notice nodata values anywhere?

# %%
band4.plot()

# %% [markdown]
# Create a new DataArray called `ndvi`.
#
# `(NIR - red) / (NIR + red)`
#
# Should be between -1 and 1.

# %% [markdown]
# Plot your new DataArray

# %% [markdown]
# Say that you are only interested in NDVI above 0.7. Write a line of code to mask out ndvi below 0.7 with `np.nan`.

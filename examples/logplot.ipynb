# %% [markdown]
# # Log scale plot Example
#
# This example plots multiple columns from a pandas dataframe onto a log scale plot.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data opening and discovery

# %%
discoveraq_all = pd.read_csv('../lessons/tabular_data/data/discoveraq-mrg10-p3b_merge_20140720_R2.ict', skiprows=182)

# %%
discoveraq_all
# Out:
#         UTC   JDAY   INDEX   FLIGHT   LOCAL_SUN_TIME   LATITUDE   LONGITUDE  \
# 0     50955    201   20001        2         7.147100  39.914451  254.873170
# 1     50965    201   20002        2         7.150076  39.912901  254.876144
# 2     50975    201   20003        2         7.153173  39.910394  254.880928
# 3     50985    201   20004        2         7.156377  39.907028  254.887326
# 4     50995    201   20005        2         7.159675  39.902955  254.895121
# ...     ...    ...     ...      ...              ...        ...         ...
# 1724  68195    201   21725        2        11.937223  39.904753  254.891682
# 1725  68205    201   21726        2        11.940132  39.903717  254.893650
# 1726  68215    201   21727        2        11.943004  39.902975  254.895066
# 1727  68225    201   21728        2        11.945862  39.902347  254.896256
# 1728  68235    201   21729        2        11.948707  39.901821  254.897273
#
#           ALTP   PRESSURE   TEMPERATURE  ...  \
# 0     1.673992   827.6601    299.250804  ...
# 1     1.667469   828.3253    298.884864  ...
# 2     1.663446   828.7359    299.028674  ...
# 3     1.654759   829.6233    299.321844  ...
# 4     1.633362   831.8123    299.731304  ...
# ...        ...        ...           ...  ...
# 1724  1.674663   827.5917    306.397654  ...
# 1725  1.673108   827.7500    307.521904  ...
# 1726  1.665915   828.4840    308.063504  ...
# 1727  1.663873   828.6924    306.451514  ...
# 1728  1.661312   828.9538    308.118144  ...
#
#        Acetic-Acid-Glycolaldehyde_MixingRatio   Isoprene_MixingRatio  \
# 0                                  -9999999.0             -9999999.0
# 1                                  -9999999.0             -9999999.0
# 2                                  -9999999.0             -9999999.0
# 3                                  -9999999.0             -9999999.0
# 4                                  -9999999.0             -9999999.0
# ...                                       ...                    ...
# 1724                               -9999999.0             -9999999.0
# 1725                               -9999999.0             -9999999.0
# 1726                               -9999999.0             -9999999.0
# 1727                               -9999999.0             -9999999.0
# 1728                               -9999999.0             -9999999.0
#
#        MVK-MACR-crotonaldehyde_MixingRatio   MEK-butanal_MixingRatio  \
# 0                               -9999999.0                -9999999.0
# 1                               -9999999.0                -9999999.0
# 2                               -9999999.0                -9999999.0
# 3                               -9999999.0                -9999999.0
# 4                               -9999999.0                -9999999.0
# ...                                    ...                       ...
# 1724                            -9999999.0                -9999999.0
# 1725                            -9999999.0                -9999999.0
# 1726                            -9999999.0                -9999999.0
# 1727                            -9999999.0                -9999999.0
# 1728                            -9999999.0                -9999999.0
#
#        Benzene_MixingRatio   Toluene_MixingRatio  \
# 0               -9999999.0            -9999999.0
# 1               -9999999.0            -9999999.0
# 2               -9999999.0            -9999999.0
# 3               -9999999.0            -9999999.0
# 4               -9999999.0            -9999999.0
# ...                    ...                   ...
# 1724            -9999999.0            -9999999.0
# 1725            -9999999.0            -9999999.0
# 1726            -9999999.0            -9999999.0
# 1727            -9999999.0            -9999999.0
# 1728            -9999999.0            -9999999.0
#
#        C8-alkylbenzenes_MixingRatio   C9-alkylbenzenes_MixingRatio  \
# 0                        -9999999.0                     -9999999.0
# 1                        -9999999.0                     -9999999.0
# 2                        -9999999.0                     -9999999.0
# 3                        -9999999.0                     -9999999.0
# 4                        -9999999.0                     -9999999.0
# ...                             ...                            ...
# 1724                     -9999999.0                     -9999999.0
# 1725                     -9999999.0                     -9999999.0
# 1726                     -9999999.0                     -9999999.0
# 1727                     -9999999.0                     -9999999.0
# 1728                     -9999999.0                     -9999999.0
#
#        Monoterpenes_MixingRatio   BC_mass
# 0                    -9999999.0  -9999999
# 1                    -9999999.0  -9999999
# 2                    -9999999.0  -9999999
# 3                    -9999999.0  -9999999
# 4                    -9999999.0  -9999999
# ...                         ...       ...
# 1724                 -9999999.0  -9999999
# 1725                 -9999999.0  -9999999
# 1726                 -9999999.0  -9999999
# 1727                 -9999999.0  -9999999
# 1728                 -9999999.0  -9999999
#
# [1729 rows x 138 columns]

# %% [markdown]
# ### Data subsetting and cleaning

# %%
discover_scat = discoveraq_all[[' UTC', ' SCAT450nm-dry_total_LARGE', 
                            ' SCAT550nm-dry_total_LARGE', ' SCAT700nm-dry_total_LARGE']]

# %%
# Clean nodata value
discover_scat = discover_scat.replace(-9999999, np.nan)
# Set UTC as an index so that pandas knows it should be the x axis
discover_scat = discover_scat.set_index(' UTC')

# %% [markdown]
# ### Plotting

# %%
# plot using the built in pandas function
discover_scat.plot()
# Out:
# <AxesSubplot:xlabel=' UTC'>

# %%
fig, ax = plt.subplots()

# plot the same pandas plot on a matplotlib specified axis
discover_scat.plot(ax=ax)

# Set the y axis to be a log scale
ax.set_yscale('log')

# Add labels
ax.set_title('Dry scattering over time')
ax.set_ylabel('Scattering LARGE')
# Out:
# Text(0, 0.5, 'Scattering LARGE')
